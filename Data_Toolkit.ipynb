# %% [markdown]
# Q1.What is NumPy, and why is it widely used in Python ?
# Ans->Numpy is a open source library ,and numpy array is its object(np.array[]) ,it is used to store data like list but it has many advantages like---
#    1)numpy is fast compare to list ,because numpy code are written in "c" (optimized)
#    2)numpy can store large amount of data so it is useful in data science,ml
#    3)numpy is useful in multidimensional array & it is useful in scientific calculation.
#
# Q2.How does broadcasting work in NumPy.
# Ans.broadcasting is a mechanism in numpy, which is used for apply mathematical operation on diffrent shape of array.
# ->in broadcasting small array is expend to fit the mathematical operation.
# ->it makes memory use efficient and faster.
#
# Q3. What is a Pandas DataFrame?
# Ans.pandas is a 2-dimensinal data structure in which data is represented in the form of rows and column,like excel-sheet.
# it make operation efficent like grouping,filtering,sorting,visualization etc.
#
# Q4. Explain the use of the groupby() method in Pandas.
# Ans.in dataframe we can make group according to colums and then apply operation like mean,sum etc by group like there is a data frame of employee name ,departments,salary.....than we can apply groupby on department and use mean operation on salary.
#
# Q5.Why is Seaborn preferred for statistical visualizations ?
# Ans.Seaborn is preferred because of it has better data visualization tools ,better color,better pallets
#              *seaborn is preferred because some statical tools are in build
#              *it works easily with pandas data frame.
#              *show relationship and distribution clearly.
#
# Q6.A What are the differences between NumPy arrays and Python lists.
# Ans. numpy array and python list both store data , but they are different in many ways:
# *python list are build in objects in python,but to use numpy array we have to import numpy library.
# *python list are build in python code but numpy is optimized in "c" code , so numpy is very fast and memory efficient compare to list.
# *operations like sort and search are slower in list because we have to use loop so complexity become O(n), but in numpy array we can directly seach and sort so in ML,DATA SCIENCE numpy is very usefull.
#
# Q7.A What is a heatmap, and when should it be used ?
# Ans.heatmap is a data visualization technique,which shows values in dataset in the form of colors.
#        *low values show in lighter color ,high values showed in darker color
#        *it is useful in machine learning and data science because data is large it is necessary to show co-relation between them .
#        *it is very compatible with pandas ,seaborn'
#        *heat map helps in feature relationship.
#
# Q8.What does the term “vectorized operation” mean in NumPy.
# Ans. 'vectorized operation' means apply mathematical operation(like addition ,multiplication) on whole of the array without using for loop, vectorized operations are possible in numpy because it used broadcasting and its code are optimized in c so they are fater and memory efficient.
#
# Q9. How does Matplotlib differ from Plotly?
# Ans.matplotlib & plotly both are data visualization tools ,but---
#                 *matplotlib give static graphs
#     but in plotly we have interactive graphs.
#                 *matplotlib is lighter and more customizable,plotly is havier(because it give inerative graphs)
#                 *matplotlib is mostly use in research papers because it give more custom feature,plotly is used in web applicaions because it is more interactive like hover ,zoom,click.
# Q10.What is the significance of hierarchical indexing in Pandas?
# Ans.hierarchical indexing or multiindexing is a mechanism in pandas in which data organised in a way so filterting ,access and reshaping of data is become easier .
#
# Q11. What is the role of Seaborn’s pairplot() function ?
# Ans. seaborn's pairplot() is data visulization tool in python , it create visual graphs between all numerical feature relaionship.
# like if there are "A","B","C" are different numerical features(column) than pairplot create relationship visuals between all combination.
#
# Q12.What is the purpose of the describe() function in Pandas ?
# Ans.the describe function in pandas is used for give quick summary of data like for numerical data it give mean,max,min,standard deviation for the data and in for "text" column it gives frequency,outliers ,count etc.
# .........*in short it gives basic understanding of data so it is very important to understand the data . but it do not give data visualization .
#
# Q13. Why is handling missing data important in Pandas.
# Ans.It is important to handle missing values (NaN/null values) because
#         *Data visualization give wrong results.
#         *machine learning library like sckit-learn can fail.
#         *average/mean etc could go wrong.
#         #there are many ways to deal with it like replace NaN value with mean of the column.
#
# Q14.What are the benefits of using Plotly for data visualization ?
# Ans.benifits:
# 1).plotly can create interactive graphs.like (hover,zoom,click{we can zoom graphs etc})
# 2).it is used in interactive web pages.
# 3).it suppot advace charts like maps,3D graphs,Animated charts,
# 4).it is easy coding than matplotlib.
#
# Q15.How does NumPy handle multidimensional arrays.
# Ans.Numpy use ndarray object to store multidimensional  array,also whole data is stored in continuous data in memory .in numpy with the help of broadcastin ,and vetorization easily mathematical operation can be done .it is very fast than list & loop because internally it's code is optimized in "c" language so it is fater and efficient in memory management .thats whay it is used in Data science and machine learning .
#
# Q16.What is the role of Bokeh in data visualization.
# Ans.Bokeh create interactive data visualization graphs,we can zoom ,click hover on them , it is used in web based browsers like chrom etc.They work on live data. like cricket scores ,stock market.
#
# Q17. Explain the difference between apply() and map() in Pandas.
# Ans.map(),apply both use a function on data but there are some diffrence ->
# (1).map() is works on series data like 1 column,but apply can  work on series data (ex. column) and a DataFrame(rows & column)
# (2)for more complex logic apply() is used and with simple data map() is used .
#
# Q18. What are some advanced features of NumPy ?
# Ans.these are the following advance feature of Numpy->
# (a)Broadcasting=array size can expend to fit mathematical operation.
# (b)Vectorization=with the help of "C" level optimized code ,without loop in fater way airthematic operation can apply on numpy array.
# (c)advance indexing=boolean indexing and fancy indexing can be done.
# (d)shape manipulation=array size can be change without data change.
# (e)powerful build in operation=like sum(),mean(),max().
# (f)memory efficient = numpy is very memory efficient compare to list .
#
# Q19.How does Pandas simplify time series analysis ?
# Ans.
# Pandas simplifies time series analysis by:
#
# Converting strings to datetime
#
# Allowing time-based indexing
#
# Supporting resampling (D, M, Y)
#
# Providing rolling calculations
#
# Enabling shift (lag/lead)
#
# Generating date ranges
#
# Handling missing time data
#
# Extracting date components
#
# Q20. What is the role of a pivot table in Pandas ?
# Ans.pivot table is a powerfull tool in pandas ,which is used to reorganise messay data and give summarized information from the data.it first group the messay data ,than apply aoperation on it like sum(),mean() etc than transform the data into table format .
#
# Q.21 Why is NumPy’s array slicing faster than Python’s list slicing ?
# Ans.Numpy's array slicing is faster than Python's list slicing because (1) in list slicing data is first copy in memory so (because of time taken in copying) list slicing is become slower ,but numpy slicing do not copy data it is just procedure of view (just create slicing data refrence)
# (2)numpy code is optimized in "C" language so it become natually faster than python .
#
# Q22. What are some common use cases for Seaborn?
# Ans.Seaborn is very powerfull library for data visualization it is very important because =>
# *it is useful to show how data is distributed (ex. histplot())
# *Create graphs between 2 variable like hours studied and marks of student.
# *categories wise data distribution (ex . bar plot ())
# *used in to represent of outliers and Data spread.
# *with the use of Heatmap shows corelation.
# *with the use of pairplot() , seaborn can show corealtion between diffrent feature.

# %%
#Q1.How do you create a 2D NumPy array and calculate the sum of each row ?

import numpy as np
a=np.array([[5,2],
            [9,6]])
print(np.sum(a))
# Out:
# 22

# %%
#Q2.Write a Pandas script to find the mean of a specific column in a DataFrame
import pandas as pd
data={"name":["ram","shyam","mohan"],
      "marks":[46,79,67]}
df=pd.DataFrame(data)
marks_mean=df["marks"].mean()
print(marks_mean)
# Out:
# 64.0

# %%
#Q3. Create a scatter plot using Matplotlib

import matplotlib.pyplot as plt
# Here x=hours studied,y=marks
x=[1,2,3,4,5,6]
y=[50,60,75,79,88,99]

plt.scatter(x,y)
plt.xlabel("HOURS STUDIED")
plt.ylabel("MARKS OBTAINED")
plt.title("Student Study Chart")

plt.show()

# %%
'''Q4. How do you calculate the correlation matrix using Seaborn and visualize it with a heatmap.'''
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.DataFrame({
    "hours": [1, 2, 3, 4, 5],
    "marks": [50, 60, 65, 70, 80],
    "sleep": [8, 7, 6, 6, 5]
})

corr=df.corr()
sns.heatmap(corr,annot=True,cmap="coolwarm")
plt.show()

# %%
#Q5.Generate a bar plot using Plotly
import plotly.express as px
data = {
    "name": ["Amit", "Rohit", "Sita"],
    "marks": [41, 90, 70]
}
fig=px.bar(data,x="name",y="marks",title="Student studied")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Q6.Create a DataFrame and add a new column based on an existing column
import pandas as pd
data={"name":[13,64,97],
      "Roll_NO":[1,2,3]}
df=pd.DataFrame(data)
df["marks"]=[94,76,88]
print(df)
# Out:
#    name  Roll_NO  marks
# 0    13        1     94
# 1    64        2     76
# 2    97        3     88

# %%
#Q7.Write a program to perform element-wise multiplication of two NumPy arrays

import numpy as np
a=np.array([[64,89],
           [84,76]])
b=np.array([[47,68],[52,36]])
c=a*b
print(c)
# Out:
# [[3008 6052]
#  [4368 2736]]

# %%
#Q8.Create a line plot with multiple lines using Matplotlib
import matplotlib.pyplot as plt
x=["jan","feb","march","april"]
y1=[100,120,134,149]
y2=[124,142,100,189]
plt.plot(x,y1,label="Parle-G")
plt.plot(x,y2,label="Britannia")
plt.xlabel("months")
plt.ylabel("Sales")
plt.title("Buiscuit sales Data")
plt.show()

# %%
'''#Q9.Generate a Pandas DataFrame and filter rows where a column value is greater than a threshold'''
import pandas as pd

# DataFrame create करना
df = pd.DataFrame({
    "name": ["Amit", "Rohit", "Sita", "Anita"],
    "marks": [80, 55, 70, 90]
})

print(df)
print("Now we are filtering the dataif threshold is 85 \n")
print(df[df["marks"]>85])
# Out:
#     name  marks
# 0   Amit     80
# 1  Rohit     55
# 2   Sita     70
# 3  Anita     90
# Now we are filtering the dataif threshold is 85
#
#     name  marks
# 3  Anita     90

# %%
#Q10. Create a histogram using Seaborn to visualize a distribution

import seaborn as sns
import matplotlib.pyplot as plt
marks=[31,31,46,46,79,79,79,56,89,32]
sns.histplot(marks)
plt.title("Marks Distribution")
plt.show()

# %%
#Q11. Perform matrix multiplication using NumPy
import numpy as np
a=np.array([[32,65],
           [78,12]])
b=np.array([[64,97],
            [98,56]])
mul=a*b
print(mul)
# Out:
# [[2048 6305]
#  [7644  672]]

# %%
#Q12.Use Pandas to load a CSV file and display its first 5 rows
import pandas as pd
df=pd.read_csv("assignment.txt")
print(df.head())

# %%
#Create a 3D scatter plot using Plotly.
import plotly.express as px
x=[5,10,15]
y=[6,12,18]
z=[7,14,21]
fig=px.scatter_3d(x=x,y=y,z=z)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
