# %% [markdown]
# Q1.What is the difference between interpreted and compiled languages ?
# Ans.in interpretted language code is executed line by line(first it convert to machine language) then executed. but in compiled lavel language code will first convert to low level language(machine language) than executed.compiled level language is faster than interpreter level language. c++ is compiler level language and php is interpreter level language.
#
# Q2.What is exception handling in Python ?
# Ans.In exception handling in python a programmers aim is to give user freindly and graceful message when error occure in programs during run time. it saves program for crashing, like if a/b,denominator can not be zero if user give b=0 : than ZerodivionError occure.we use try ,except,finally in exception handling in python.
#
#
# Q3. What is the purpose of the finally block in exception handling ?
# Ans.finally is executed whether error occured or not ,or even after return statement (either in try or except ).
#     *PURPOSE==finally release resources like close file
#     *it colse database connections/network connection.
# Q4.What is logging in Python ?
# Ans. logging in python is a build in mechanism in which we can record message about our program execution stage,like debugging,info,error or critical.(we import logging module for that).
#
# Q5. What is the significance of the __del__ method in Python.
# Ans. __del__ is build in method in python ,when we call it delete object , it is like reverse of __init__ method, it free up resources.
#
# Q6. What is the difference between import and from ... import in Python ?
# Ans.import.... is used for impoting some python module like import math, from ....used when we want to import something from module like from math import sqrt(square function). first must used when we need many things from module , when we want specific function than we should use second(from ......).
#
# Q7.How can you handle multiple exceptions in Python ?
# Ans.there are many ways like --
#  (a).use of multiple except blocks like
#       except ValueErroe
#          print(.......)
#       except ZeroDivisionError
#  (b).use of tuple like
#        except(valueerror,zerodivionerror)
# (c) use base exception class
#         except exception as e
#  (d) custom excetion (using raise keyword)
#
# Q8. What is the purpose of the with statement when handling files in Python ?
# Ans.with is used for close file after execution (even error occure during execution), it free up resources ,if we do not use with than it can cause error OR curropt file .
#
# Q9.What is the difference between multithreading and multiprocessing ?
# Ans.multithreading vs multiprocessing
# --(1).in multithreading all threads shares a common memory ,but in multiprocessing all process have diffrent memoty
# --(2).multithreading is not true parallel it is concurrent ,but multiprocessing is true parallel process.
# --(3).Ind multithreading GIL is common to all process , when one process release gil other pick it ,but in multiprocessing every process has its own GIL and memory .
#
#
# Q10.What are the advantages of using logging in a program ?
# Ans.logging is a build in  mechanism in python in which programe execution stages are record like debug,info,error,critical etc.
#     -----advantages--*it will very useful for security of program, user it is better than print because it not only show in consol but in file also and email(we can save log file ) so it will be accessible later also,in print there is no severity level but in log there are diffrent severity level like error or critical etc , in print there is no timestamp but in log there is timestamp .
# Q11. What is memory management in Python ?
# Ans. memory management means how program takes use of  RAM memory , how it give memory to objects,how it delete memory of objects when they are not in use ----these are following methods
#       objects memory is manage by heap memory,refrence counting(when object is no use it become 0),and garbage collection(import gc).
#
# Q12.What are the basic steps involved in exception handling in Python ?
# Ans.these are following steps in python exception handling:--
#      *try:==code of block where error can occure come in try section.
#      *exception==when error occure it is deal in exception block like value error or zerodiviionerror.
#      *finally=this block is executed either error is occure or not .
#
# Q13.  Why is memory management important in Python ?
# Ans.following are the reason of memory management--
#     (a).it efficiently use RAM memory.
#     (b).programe runs faster
#     (c).memory leaks reduces.
#     (d).increase system stability(beacause if ram not used efficiently it can hang or crash.
# Q14. What is the role of try and except in exception handling ?
# Ans.try contains the code that might cause an error.
# except catches that error and runs alternative code if something goes wrong — preventing the program from crashing.
#
# Q15.How does Python's garbage collection system work ?
# Ans.python garbage collection works in 2 ways (1).refrence counting=if "x=2"than variable x is refer the object 10 so refrece count is 1 ,if x=y,than now there are 2 varibable which are refer to object 10, when refernce count become 0 (like del x,del y ).
#       but when there is cyclic situation like one varibale points to other than it is not working
# (2).Cyclic Garbage Collection=In circular reference this mechanism delete object,in cyclic garbage collection objects are devided in 3 categories==generation0,1,2[here generation 0is for newly created object check ocasinally].
#
# Q16.What is the purpose of the else block in exception handling ?
# Ans.else block is run when no error is occured example:
#    try:
#        code block
#    except:
#         run when there an error
#    else:
#         run where no error in code during run time .
# Q17. What are the common logging levels in Python ?
# Ans.These are the common logging levels:
#      (a)Debug
#      (b)INFO
#      (c)warning
#      (d)error
#      (e)critical
# Q18. What is the difference between os.fork() and multiprocessing in Python ?
# Ans.os.fork() and multiprocessing both are used to create multiple processes but there are many diffrences like:
#      a) os.fork is work only in linus/unix but multiprocessing work in all plateform like windows,linux,unix etc.
#      b)in os.fork programmer have to do many thigs himself ,but in multiprocessing there are build in tools like pipe,queue,manage etc
#      c)in os.fork() it is difficult to communicate between processes but in multiprocessing for communication between process can be easily done with the help of pipe,manage,queue etc.
#
# Q19.What is the importance of closing a file in Python ?
# Ans.we can close file with "f.close" or using"with" ,closing of file is very important either programe run successfully or not these are 2 main benifit of it *with clossing file ,file can be courrupted *after closing file resources are released* database connection and network connections are freed*
#
# Q20.What is the difference between file.read() and file.readline() in Python ?
# Ans.when we use file.read() it reads whole file in one time (so whole file is load in RAM memory) so it is useful in small file but not in large files because it occupy large part of ram so execution is become slow. other is file.readline() it reads file line by line ,when we call it it read first line , again call and it read another line it only thats why it is usefull in large files reading because it occupy very less memory . example:
# file.radline()
#      #read first line
# file.readline()
#     #read second line
#
# Q21. What is the logging module in Python used for ?
# Ans. logging module in python is used for record diffrent stage of system during program execution like debug,info,warning,error,critical. logging is diffrent from print because we can save its message in files, email, and with network so for future analysis they can be used for system security and performance.
#
# Q22.What is the os module in Python used for in file handling ?
# Ans.with the help of os module we can interact with operating system,it is mainly useful in creating file ,manage files ,check directoies & delete files.
#
# Q23.What are the challenges associated with memory management in Python ?
# Ans.The main challenges in Python memory management include reference cycles, memory fragmentation, high memory usage by large objects, potential memory leaks, garbage collection overhead, and additional memory overhead of Python objects.
#
# Q24. How do you raise an exception manually in Python .
# Ans.we can raise exception manually by using "raise" keyword here is the example
#       try:
#       age=int(input("Enter your age"))
#       if age<0:
#          raise Exception("age can not be negative")
#
#       except Exception as e:
#            print("Error",e)
#
# Q25.Why is it important to use multithreading in certain applications?
# Ans.in modern applications there is need to run many task simantaniously we can wait another to complete first like on google doc one thred can autho save , one thread is realted to text formatting ,one thread is spelling check to they must run almost simantaniously, so to reduce responce time ,keep apps responsive,keep smooth gaming experience and running background task without interrupting other .

# %%
'''Q1.How can you open a file for writing in Python and write a string to it'''
with open("assignment.txt","w") as f:
  f.write("this is data science course ")

# %%
'''Q2.Write a Python program to read the contents of a file and print each line'''

with open("assignment.txt","r") as f:
  for i in f:
    print(i)

# %%
'''Q3. How would you handle a case where the file doesn't exist while trying to open it for reading'''

try:
  with open("assignment.txt","r") as f:
    result=f.read()
    print(result)
except FileNotFoundError:
  print("Error:file no found create file first")
finally:
  print("exception handling ")
# Out:
# Error:file no found create file first
# exception handling

# %%
'''Q4.Write a Python script that reads from one file and writes its content to another file'''

with open("my_file.txt","r") as f1:
  data=f1.read()
with open("my_file.txt","w") as f2:
  final_result=f2.write(data)
  print(final_result)

# %%
'''Q5.How would you catch and handle division by zero error in Python'''
try:
  a=int(input("enter the value of a "))
  b=int(input("enter the value of b "))
  c=a/b
  print(c)
except ZeroDivisionError:
  print("denominator can not be zero")
finally:
  print("program execution is completed")
# Out:
# enter the value of a 5
# enter the value of b 0
# denominator can not be zero
# program execution is completed

# %%
'''Q6.Write a Python program that logs an error message to a log file when a division by zero exception occurs'''
import logging
logging.basicConfig(filename="assignment.log",level=logging.ERROR,format="%(asctime)s-%(levelname)s-%(message)s")
try:
  a=int(input("enter the value of a "))
  b=int(input("enter the value of b "))
  c=a/b
  print(c)
except ZeroDivisionError:
  print("denominator value can not be zero ")
# Out:
# enter the value of a 5
# enter the value of b 0
# denominator value can not be zero

# %%
'''Q7.How do you log information at different levels (INFO, ERROR, WARNING) in Python using the logging module'''
import logging

logging.basicConfig(level=logging.DEBUG)

logging.info("Server started successfully")       # General info
logging.warning("Low memory detected")            # Something unexpected
logging.error("Failed to connect to database")    # Serious problem

# %%
'''Q8.Write a program to handle a file opening error using exception handling'''
try:
  with open("assignment.txt","r") as f:

    data=f.read()
    print(data)

except FileNotFoundError:
  print("create file first")
# Out:
# this is Data science course

# %%
'''Q9.How can you read a file line by line and store its content in a list in Python'''

with open("assignment.txt","r") as f:
   data=f.readline()
   print(data)
# Out:
# this is Data science course

# %%
'''Q10.How can you append data to an existing file in Python ?'''
with open("assignment.txt","a") as f:
 f.write("this is python-exceptional handling topic  ")
# Out:
# this is python-exceptional handling topic  this is python-exceptional handling topic  this is python-exceptional handling topic

# %%
'''Q11.Write a Python program that uses a try-except block to handle an error when attempting to access a dictionary key that doesn't exist'''

try:
  Data={"name":"A","age":15,}
  x=Data["height"]
  print(x)

except KeyError:
  print("the requested key in dictionalry is not found")
# Out:
# the requested key in dictionalry is not found

# %%
'''Q12. Write a program that demonstrates using multiple except blocks to handle different types of exceptions .'''

try:
  a=int(input("Enter the value of a "))
  b=int(input("Enter the value of b "))
  c=a/b
  print(c)
except ValueError:
  print("enter the correct input")
except ZeroDivisionError:
  print("denominator can not be zero " )
# Out:
# Enter the value of a ria
# enter the correct input

# %%
''' Q13.How would you check if a file exists before attempting to read it in Python'''

import os

filename="data.txt"

if os.path.exists("data.txt"):
  with open("data.txt","r") as f:
    x=f.read()
    print(x)

# %%
'''Q14.Write a program that uses the logging module to log both informational and error messages'''

import logging
logging.basicConfig(filename="assignment.txt",level=logging.INFO
                    ,format="%(levelname)s-%(message)s")
logging.info("program is now starting")
try:
  x = int(input("Enter a number: "))
  y = 10 / x
  logging.info("Division performed successfully")

except Exception as e:
    logging.error("An error occurred: %s", e)

logging.info("Program finished")
# Out:
# Enter a number: e
# ERROR:root:An error occurred: invalid literal for int() with base 10: 'e'

# %%
'''Q15. Write a Python program that prints the content of a file and handles the case when the file is empty'''

try:
  with open("assignment.txt","r") as f:
    x=f.read()
    if x=="":
      print("file is empty")
    else:
      print("content of file \n")
      print(x)
except FileNotFoundError:
  print("FIRST create the file ")
# Out:
# FIRST create the file

# %%
'''Q16Demonstrate how to use memory profiling to check the memory usage of a small program'''
from memory_profiler import profile

@profile
def my_function():
    # Step 1 — allocate a large list
    big_list = [x ** 2 for x in range(100_000)]

    # Step 2 — create a dict from the list
    lookup = {v: i for i, v in enumerate(big_list)}

    # Step 3 — delete the original list
    del big_list

    # Step 4 — return the dict
    return lookup

if __name__ == "__main__":
    result = my_function()
sa

# %%
'''Q18. Write a Python program to create and write a list of numbers to a file, one number per line '''

num=[12,5,78,56,35]
with open("numbers.txt","w") as f:
  for i in num:
    f.write(f"{i}\n")

# %%
'''Q19.How would you implement a basic logging setup that logs to a file with rotation after 1MB'''

# %%
'''Q19.Write a program that handles both IndexError and KeyError using a try-except block'''

try:
  list_a=[10,23,64,98]
  data={"name":"ram","rolo_no":89}
  print(list_a[2])
  print(data["city"])
except (IndexError,KeyError):
  print("give correct index/kEY value")
# Out:
# 64
# give correct index/kEY value

# %%
'''Q20. How would you open a file and read its contents using a context manager in Python'''
# file ko context manager se open karna
with open("data.txt", "r") as f:

    # file ka content read karna
    x = f.read()

    print(x)

# %%
''' Write a Python program that reads a file and prints the number of occurrences of a specific word'''

with open("assignment.txt","r") as f:
  text=f.read()
  x=text.count("data")
  print(x)
# Out:
# 0

# %%
'''Q22.How can you check if a file is empty before attempting to read its contents'''
import os
with open("assignment1.txt","w") as f:


  if os.path.getsize("assignment1.txt")==0:
    print("file is empty")
  else:
    x=f.read()
    print(x)
# Out:
# file is empty

# %%
'''Q23. Write a Python program that writes to a log file when an error occurs during file handling.'''
import logging
logging.basicConfig(filename="assignment.txt",level=logging.ERROR)
try:
  with open("assignment.txt","r") as f:
    x=f.read()
    print(x)
except Exception as e:
  logging.error("error occured while handling the file ",e)
